# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
profile_df = pd.read_csv('profile.csv')
profile_df
# Out:
#              operation  execution time  num_threads
# 0           Generating    76988.000000            7
# 1           Encrypting     9743.320000            7
# 2            encryptVx      913.786500            7
# 3               evalMV     8092.773333            7
# 4            modDownTo       19.727700            7
# 5    modDownToAndEqual       16.496000            7
# 6              evalAdd       16.835000            7
# 7      evalAddAndEqual       12.205000            7
# 8       evalSigmoid(3)     6316.035000            7
# 9       evalSigmoid(5)     6945.580000            7
# 10      evalSigmoid(7)     8162.465000            7
# 11     evalMulAndEqual     2113.463333            7
# 12         evalTanh(3)     5971.430000            7
# 13         evalTanh(5)     6062.910000            7
# 14         evalTanh(7)     7044.720000            7
# 15            evalOnem       33.610000            7
# 16            evalTrx1     6483.010000            7
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='operation', y='execution time', data=profile_df.query("operation=='evalAdd'"), hue='num_threads')

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='operation', y='execution time', data=profile_df.query("num_threads in [1, 2, 4, 8, 16]").query("operation in ['Generating', 'Encrypting', 'bootstrap']"), hue='num_threads')
